# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
import gymnasium as gym

env = gym.make("LunarLander-v2")

observation, info = env.reset()

for _ in range(20):
  action = env.action_space.sample()
  print("Action taken:", action)

  observation, reward, terminated, truncated, info = env.step(action)

  if terminated or truncated:
      print("Environment is reset")
      observation, info = env.reset()

env.close()
# Out:
# Action taken: 0
# Action taken: 3
# Action taken: 1
# Action taken: 1
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 3
# Action taken: 0
# Action taken: 1
# Action taken: 1
# Action taken: 0
# Action taken: 1
# Action taken: 2
# Action taken: 3
# Action taken: 2
# Action taken: 1
# Action taken: 2
# Action taken: 1
# Action taken: 2

# %%
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-2.3310296e-03 -8.3580959e-01 -2.6837227e+00  2.0819643e+00
#   1.7402809e+00  1.6742150e-01  2.3560120e-01  2.7356419e-01]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 2

# %%
env = make_vec_env('LunarLander-v2', n_envs=16)

# %%
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=1000000)

model_name = "ppo-LunarLander-v2"
# model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.3     |
# |    ep_rew_mean     | -186     |
# | time/              |          |
# |    fps             | 9179     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.9        |
# |    ep_rew_mean          | -149        |
# | time/                   |             |
# |    fps                  | 6125        |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005495607 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00094     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.76e+03    |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 4.94e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 5438         |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0071294485 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000392     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 848          |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00497     |
# |    value_loss           | 2.25e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.7         |
# |    ep_rew_mean          | -129         |
# | time/                   |              |
# |    fps                  | 5265         |
# |    iterations           | 4            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0059353206 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00488      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 619          |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00507     |
# |    value_loss           | 2.03e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 5146        |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009635897 |
# |    clip_fraction        | 0.0964      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00346    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 356         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -99.2       |
# | time/                   |             |
# |    fps                  | 5062        |
# |    iterations           | 6           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008013725 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.000413   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 294         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 748         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -80         |
# | time/                   |             |
# |    fps                  | 4999        |
# |    iterations           | 7           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008401344 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -1.22e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 254         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 537         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.1        |
# |    ep_rew_mean          | -73         |
# | time/                   |             |
# |    fps                  | 4988        |
# |    iterations           | 8           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.006442873 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -1.59e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 295         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 417         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.5       |
# |    ep_rew_mean          | -54.4      |
# | time/                   |            |
# |    fps                  | 4952       |
# |    iterations           | 9          |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.01077012 |
# |    clip_fraction        | 0.0926     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | -1e-05     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 213        |
# |    n_updates            | 32         |
# |    policy_gradient_loss | -0.00678   |
# |    value_loss           | 425        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 4836        |
# |    iterations           | 10          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.007030702 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -6.44e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 159         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00405    |
# |    value_loss           | 383         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | -24.1        |
# | time/                   |              |
# |    fps                  | 4761         |
# |    iterations           | 11           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0091693485 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -4.53e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 196          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 460          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | -17.3        |
# | time/                   |              |
# |    fps                  | 4734         |
# |    iterations           | 12           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0067195613 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 2.62e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 328          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00358     |
# |    value_loss           | 541          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 136          |
# |    ep_rew_mean          | -7.29        |
# | time/                   |              |
# |    fps                  | 4572         |
# |    iterations           | 13           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0056243055 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | -1.25e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 329          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 607          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 170        |
# |    ep_rew_mean          | 0.528      |
# | time/                   |            |
# |    fps                  | 4370       |
# |    iterations           | 14         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 229376     |
# | train/                  |            |
# |    approx_kl            | 0.00599856 |
# |    clip_fraction        | 0.0417     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 1.72e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 397        |
# |    n_updates            | 52         |
# |    policy_gradient_loss | -0.00188   |
# |    value_loss           | 704        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 6.99        |
# | time/                   |             |
# |    fps                  | 3999        |
# |    iterations           | 15          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.008945648 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -0.00423    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 460         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 719         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 17.5        |
# | time/                   |             |
# |    fps                  | 3709        |
# |    iterations           | 16          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.007452673 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0148      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 169         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 423         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 436          |
# |    ep_rew_mean          | 26.7         |
# | time/                   |              |
# |    fps                  | 3398         |
# |    iterations           | 17           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0065572346 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.433        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 165          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00382     |
# |    value_loss           | 320          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 513         |
# |    ep_rew_mean          | 38.8        |
# | time/                   |             |
# |    fps                  | 3182        |
# |    iterations           | 18          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005375113 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.5        |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 156         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 606         |
# |    ep_rew_mean          | 42.8        |
# | time/                   |             |
# |    fps                  | 3017        |
# |    iterations           | 19          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.007990465 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40          |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 172         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 667         |
# |    ep_rew_mean          | 45.3        |
# | time/                   |             |
# |    fps                  | 2905        |
# |    iterations           | 20          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.006963824 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.3        |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 236         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 680         |
# |    ep_rew_mean          | 49.1        |
# | time/                   |             |
# |    fps                  | 2803        |
# |    iterations           | 21          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.004480894 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 151         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 219         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 738          |
# |    ep_rew_mean          | 57           |
# | time/                   |              |
# |    fps                  | 2714         |
# |    iterations           | 22           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0046204543 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.3         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 135          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 744         |
# |    ep_rew_mean          | 61.8        |
# | time/                   |             |
# |    fps                  | 2636        |
# |    iterations           | 23          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.006327723 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.6        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 68.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 788          |
# |    ep_rew_mean          | 66.8         |
# | time/                   |              |
# |    fps                  | 2559         |
# |    iterations           | 24           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0065797893 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.1         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000883    |
# |    value_loss           | 160          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 803        |
# |    ep_rew_mean          | 69.4       |
# | time/                   |            |
# |    fps                  | 2502       |
# |    iterations           | 25         |
# |    time_elapsed         | 163        |
# |    total_timesteps      | 409600     |
# | train/                  |            |
# |    approx_kl            | 0.00807547 |
# |    clip_fraction        | 0.0327     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.884      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.7       |
# |    n_updates            | 96         |
# |    policy_gradient_loss | -0.00062   |
# |    value_loss           | 113        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 851          |
# |    ep_rew_mean          | 76.6         |
# | time/                   |              |
# |    fps                  | 2456         |
# |    iterations           | 26           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0045341207 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.1         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000853    |
# |    value_loss           | 119          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 832          |
# |    ep_rew_mean          | 77.5         |
# | time/                   |              |
# |    fps                  | 2419         |
# |    iterations           | 27           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0039619575 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.893        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.8         |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 82.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 807          |
# |    ep_rew_mean          | 74.4         |
# | time/                   |              |
# |    fps                  | 2394         |
# |    iterations           | 28           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0052313576 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.3         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 138          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 834        |
# |    ep_rew_mean          | 81.6       |
# | time/                   |            |
# |    fps                  | 2363       |
# |    iterations           | 29         |
# |    time_elapsed         | 201        |
# |    total_timesteps      | 475136     |
# | train/                  |            |
# |    approx_kl            | 0.00404077 |
# |    clip_fraction        | 0.0276     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 60.8       |
# |    n_updates            | 112        |
# |    policy_gradient_loss | -0.00155   |
# |    value_loss           | 123        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 850          |
# |    ep_rew_mean          | 93.4         |
# | time/                   |              |
# |    fps                  | 2334         |
# |    iterations           | 30           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0053482642 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.3         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 62.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 844          |
# |    ep_rew_mean          | 96.5         |
# | time/                   |              |
# |    fps                  | 2312         |
# |    iterations           | 31           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0063503548 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.7         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 89.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 821         |
# |    ep_rew_mean          | 88          |
# | time/                   |             |
# |    fps                  | 2280        |
# |    iterations           | 32          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.005838303 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 90.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 845          |
# |    ep_rew_mean          | 95.7         |
# | time/                   |              |
# |    fps                  | 2245         |
# |    iterations           | 33           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0053725755 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.843        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56           |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 169          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 847          |
# |    ep_rew_mean          | 96.8         |
# | time/                   |              |
# |    fps                  | 2215         |
# |    iterations           | 34           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0048698382 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.7         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000693    |
# |    value_loss           | 62.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 866          |
# |    ep_rew_mean          | 99.9         |
# | time/                   |              |
# |    fps                  | 2194         |
# |    iterations           | 35           |
# |    time_elapsed         | 261          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0051973164 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.9         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.000682    |
# |    value_loss           | 62.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 871         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 2177        |
# |    iterations           | 36          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.004066526 |
# |    clip_fraction        | 0.0279      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.51        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 62.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 883          |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 2158         |
# |    iterations           | 37           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0055687856 |
# |    clip_fraction        | 0.0587       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.9         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | 0.00058      |
# |    value_loss           | 56.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 919          |
# |    ep_rew_mean          | 121          |
# | time/                   |              |
# |    fps                  | 2141         |
# |    iterations           | 38           |
# |    time_elapsed         | 290          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0069369636 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.995       |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.36         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.000464    |
# |    value_loss           | 51.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 125          |
# | time/                   |              |
# |    fps                  | 2131         |
# |    iterations           | 39           |
# |    time_elapsed         | 299          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0068272073 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.67         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 20.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 948          |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 2117         |
# |    iterations           | 40           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0051879436 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.948       |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81           |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.000552    |
# |    value_loss           | 43.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 948          |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 2103         |
# |    iterations           | 41           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0048699086 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.000186     |
# |    value_loss           | 8.69         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 958          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 2088         |
# |    iterations           | 42           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0049585113 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.28         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 7.39         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 972          |
# |    ep_rew_mean          | 143          |
# | time/                   |              |
# |    fps                  | 2068         |
# |    iterations           | 43           |
# |    time_elapsed         | 340          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0046728565 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.835       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.2         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 31.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 2046        |
# |    iterations           | 44          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.002866169 |
# |    clip_fraction        | 0.0291      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.867      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.53        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.000284   |
# |    value_loss           | 47          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 970          |
# |    ep_rew_mean          | 149          |
# | time/                   |              |
# |    fps                  | 2036         |
# |    iterations           | 45           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0075583113 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.837       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.92         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 46.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 945         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 2028        |
# |    iterations           | 46          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.003422215 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000109   |
# |    value_loss           | 48.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 877          |
# |    ep_rew_mean          | 175          |
# | time/                   |              |
# |    fps                  | 2026         |
# |    iterations           | 47           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0064488477 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.734       |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.6         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 154          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 799          |
# |    ep_rew_mean          | 188          |
# | time/                   |              |
# |    fps                  | 2026         |
# |    iterations           | 48           |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0047382424 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 370          |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 339          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 698         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 2030        |
# |    iterations           | 49          |
# |    time_elapsed         | 395         |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.004431163 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 136         |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 289         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 578          |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 2038         |
# |    iterations           | 50           |
# |    time_elapsed         | 401          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0052693402 |
# |    clip_fraction        | 0.0549       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.1         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 315          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 418         |
# |    ep_rew_mean          | 245         |
# | time/                   |             |
# |    fps                  | 2050        |
# |    iterations           | 51          |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.006495497 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.763      |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 237         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 2062        |
# |    iterations           | 52          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.004843098 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.9        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 293         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 328          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 2075         |
# |    iterations           | 53           |
# |    time_elapsed         | 418          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0031905565 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 151          |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 334          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 312          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 2088         |
# |    iterations           | 54           |
# |    time_elapsed         | 423          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0042746654 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.8         |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81.6         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | 0.000399     |
# |    value_loss           | 158          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 297          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 2101         |
# |    iterations           | 55           |
# |    time_elapsed         | 428          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0042625736 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.799       |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.2         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 208          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 303         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 2113        |
# |    iterations           | 56          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.005207395 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.9        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 302         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 323          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 2124         |
# |    iterations           | 57           |
# |    time_elapsed         | 439          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0032203768 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.773       |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.25         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | 0.000115     |
# |    value_loss           | 117          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 2134        |
# |    iterations           | 58          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.004276015 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.791      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 228         |
# |    policy_gradient_loss | -0.000938   |
# |    value_loss           | 44.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 328          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 2140         |
# |    iterations           | 59           |
# |    time_elapsed         | 451          |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0052616666 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.3         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 80.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 317          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 2148         |
# |    iterations           | 60           |
# |    time_elapsed         | 457          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0028634472 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.785       |
# |    explained_variance   | 0.888        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 83.3         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | 0.000591     |
# |    value_loss           | 180          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 309          |
# |    ep_rew_mean          | 258          |
# | time/                   |              |
# |    fps                  | 2158         |
# |    iterations           | 61           |
# |    time_elapsed         | 463          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0047605867 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.3         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 187          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | 265         |
# | time/                   |             |
# |    fps                  | 2168        |
# |    iterations           | 62          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.003965971 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.773      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.09        |
# |    n_updates            | 244         |
# |    policy_gradient_loss | -0.000221   |
# |    value_loss           | 13.6        |
# -----------------------------------------

# %%
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=261.07 +/- 24.641941981200464
